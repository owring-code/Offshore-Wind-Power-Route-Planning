# %% [markdown]
# 4,5
# 5,1
# 4,6
# 5,7
# 6,4
# 9,4
# 6,13
# 9,11
# 9,13
# 10,7
# 13,8
# 15,11
#
# A A A A A B B B B B B B

# %%
print(int(1/2))
# Out:
# 0

# %%
a = [0,0]+list(map(int,input().split()))
print(a)
# Out:
# [0, 0, 1, 2, 3, 2]

# %%
n = 3
dep =[0]*(n+1)
print(dep)
# Out:
# [0, 0, 0, 0]

# %%
A = list(map(int, input()))
print(A)
# Out:
# [1, 2, 3, 4]

# %%
np = [[1,2,3],[4,5,6]]
maxi = max(np[0:1][0])
print(np[1:3][1:3])
# Out:
# []

# %%
1+2+3+4<12
# Out:
# True

# %%
print(' ',end='1')
# Out:
#  1

# %% [markdown]
# 9.03,4.25
# 7.46,6.71
# 0.71,5.91
# 23.17,19.41
# 22.28,14.10
# 19.38,10.31
# 12.09,13.80
# 10.09,19.26
# 13.12,14.22
# 24.83,20.81
# 47.58,32.52
# 36.23,44.20
# 47.67,28.73
# 42.51,49.19
# 27.11,46.94
# 31.47,37.94
# 44.49,45.71
# 37.72,44.62
# 37.21,44.65
# 30.06,44.52

# %% [markdown]
# A A A A A A A A A A B B B B B B B B B B

# %% [markdown]
# 4,7
# 10,10
# 17,5.5
# 16,9
# 7,15
# 3,25
# 18,20
# 25,15
# 20,15
#
# 20,35
# 25,35
# 35,32
# 35,35
# 35,45
# 45,40
# 50,30
# 37,20
#
# A A A A A A A A A B B B B B B B B
#
# (22, 28), (25, 28), (28, 25), (28, 28)

# %%
list_start = [(22, 28), (25, 28), (28, 28)]
for x, y in list_start[:-1]:
    plt.scatter(x, y, c="r", marker="o")

x, y = list_start[-1]
plt.scatter(x, y, c="r", marker="o", label='list_start')  # 只有这个会显示在图例中

# %%
obs = [[20, 35], [25, 35], [35, 32], [35, 35], [35, 45], [45, 40], [50, 30]]

# %% [markdown]
# 4,7
# 10,10
# 16,9
# 12,12
# 7,15
# 3,25
# 18,20
# 19,30
# 25,15
# 20,15
# 20,35
# 25,37
# 35,38
# 35,30
# 41,45
# 50,30
# 37,20
# 25,43
# 45,35
#
# A A A A A A A A A A B B B B B B B B B

# %% [markdown]
# 43,46
# 40,40
# 44.5,33
# 41,34
# 38,38
# 35,43
# 25,47
# 30,32
# 20,31
# 35,25
# 35,30
# 15,30
# 13,25
# 18,15
# 12,26.5
# 20,15
# 5,5
# 20,0
# 30,13
# 7,25
# 25,15
